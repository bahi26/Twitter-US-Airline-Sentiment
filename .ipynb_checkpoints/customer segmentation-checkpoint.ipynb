# %%
#importing the data
import numpy as np
import pandas as pd
from IPython.display import display # Allows the use of display() for DataFrames
import matplotlib.pyplot as plt 
import seaborn as sns
data = pd.read_csv("Mall_Customers.csv")
data.head(5)
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# dropping the CustomerID cell

# %%
del data['CustomerID']
display(data.describe())
# Out:
#               Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000          200.000000              200.000000
# mean    38.850000           60.560000               50.200000
# std     13.969007           26.264721               25.823522
# min     18.000000           15.000000                1.000000
# 25%     28.750000           41.500000               34.750000
# 50%     36.000000           61.500000               50.000000
# 75%     49.000000           78.000000               73.000000
# max     70.000000          137.000000               99.000000

# %%
plt.bar([1,2],data['Gender'].value_counts())
plt.xticks([1,2],data['Gender'].value_counts().index.values,rotation=0)
plt.ylabel('Count')
plt.xlabel('Gender')
plt.title('Count per Gender')
# Out:
# Text(0.5,1,'Count per Gender')

# %%
pd.scatter_matrix(data, alpha = 0.3, figsize = (14,8), diagonal = 'kde');
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: pandas.scatter_matrix is deprecated, use pandas.plotting.scatter_matrix instead
#   """Entry point for launching an IPython kernel.

# %%
data=pd.get_dummies(data)
data.head()
# Out:
#    CustomerID  Age  Annual Income (k$)  Spending Score (1-100)  Gender_Female  \
# 0           1   19                  15                      39              0
# 1           2   21                  15                      81              0
# 2           3   20                  16                       6              1
# 3           4   23                  16                      77              1
# 4           5   31                  17                      40              1
#
#    Gender_Male
# 0            1
# 1            1
# 2            0
# 3            0
# 4            0

# %%
del data['Gender_Female']
log_data = np.log(data[['Age','Annual Income (k$)','Spending Score (1-100)']])

# %%
from sklearn.cluster import KMeans
from scipy.spatial.distance import cdist
def elbow(data,n):
    distortions = []
    k = 1
    K = []
    while k < n+1:
        K.append(k)
        kmeanModel = KMeans(n_clusters=k).fit(data)
        distortions.append(sum(np.min(cdist(data, kmeanModel.cluster_centers_, 'euclidean'), axis=1)) / data.shape[0])
        k += 1

    # # Plot the elbow
    plt.plot(K, distortions, 'bx-')
    plt.xlabel('Number of cluster')
    plt.ylabel('Distortion')
    plt.title('The Elbow Method showing the optimal k')
    plt.show()
    return

# %%
elbow(log_data,10)

# %%
kmeanModel = KMeans(n_clusters=5).fit(log_data)
centroids = kmeanModel.cluster_centers_
centroids
# Out:
# array([[3.90785034, 3.9442439 , 3.81849249],
#        [3.69512686, 4.46193766, 2.81481884],
#        [3.34831744, 4.30619706, 4.2171316 ],
#        [3.72145822, 3.55852174, 1.70756196],
#        [3.24448846, 3.20150491, 4.23111941]])
